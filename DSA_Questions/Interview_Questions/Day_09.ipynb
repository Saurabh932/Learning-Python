# %%
def twoSum(arr, target):
    seen = {}
    
    for i, num in enumerate(arr):
        needed = target - num
        
        if needed in seen:
            return [seen[needed], i]
        
        seen[num] = i
        
print(twoSum([2,7,11,15], 9))
print(twoSum([3,2,4], 6))
print(twoSum([3,3], 6))
# Out:
# [0, 1]
# [1, 2]
# [0, 1]

# %%
def longestUniqueSubstring(s):
    sub_length = 0
    seen = set()
    left = 0
    
    for right in range(len(s)):
        while s[right] in seen:    # If duplicate found, shrink the window
            seen.remove(s[left])
            left += 1
        
        # Adding the current element    
        seen.add(s[right])
        
        # Updating the max length
        sub_length = max(sub_length, right-left+1)
        
    return sub_length
        

print(longestUniqueSubstring("abcabcbb"))  # 3
print(longestUniqueSubstring("bbbbb"))     # 1
print(longestUniqueSubstring("pwwkew"))    # 3
print(longestUniqueSubstring(""))          # 0
print(longestUniqueSubstring("dvdf"))      # 3
# Out:
# 3
# 1
# 3
# 0
# 3

# %%
def merge(nums1, m, nums2, n):
    '''Brute Force'''
    # for i in range(n):
    #     nums1[m+i] = nums2[i]
        
    # return sorted(nums1)
    
    
    '''Optimized'''
    idx = m+n-1
    i = m-1
    j = n-1
    
    while i>=0 and j>=0:
        if nums1[i] >= nums2[j]:
            nums1[idx] = nums1[i]
            idx -= 1
            i -= 1
            
        else:
            nums1[idx] = nums2[j]
            idx -= 1
            j -= 1
    
    
    while j >= 0:
        nums1[idx] = nums2[j]
        idx -= 1
        j -= 1
                    
    return nums1
                
print(merge(nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3))
# Out:
# [1, 2, 2, 3, 5, 6]

# %% [markdown]
# ### 136. Single Number
# Solved
# Easy
# Topics
# premium lock icon
# Companies
# Hint
# Given a non-empty array of integers nums, every element appears twice except for one. Find that single one.
#
# You must implement a solution with a linear runtime complexity and use only constant extra space.
#
#
#
# Example 1:
#
# Input: nums = [2,2,1]
#
# Output: 1
#
# Example 2:
#
# Input: nums = [4,1,2,1,2]
#
# Output: 4
#
# Example 3:
#
# Input: nums = [1]
#
# Output: 1

# %%
def singleNumber(nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        # freq = {}
        # for ele in nums:
        #     freq[ele] = freq.get(ele, 0) + 1

        # for ele in nums:
        #     if freq[ele] == 1:
        #         return ele
        
        result = 0

        for num in nums:
            result ^= num

        return result
    
    
print(singleNumber([2,2,1]))
# Out:
# 1
